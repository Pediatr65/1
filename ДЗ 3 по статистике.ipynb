# %% [markdown]
# Вы хотите узнать, как много значит ранг игрока в теннисе. Проверьте следующие утверждения:
#
# а) Если ранг игрока выше более, чем на 20 позиций, то в среднем он будет выигрывать с большей вероятностью. (Если хотите проверить статистически — формируйте выборку как отклонение от ожидаемого количества побед при случайном исходе);

# %%
import numpy as np
import glob
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !git clone https://github.com/JeffSackmann/tennis_atp
# Out:
# Cloning into 'tennis_atp'...
# Updating files:  71% (125/174)
# Updating files:  72% (126/174)
# Updating files:  73% (128/174)
# Updating files:  74% (129/174)
# Updating files:  75% (131/174)
# Updating files:  76% (133/174)
# Updating files:  77% (134/174)
# Updating files:  78% (136/174)
# Updating files:  79% (138/174)
# Updating files:  80% (140/174)
# Updating files:  81% (141/174)
# Updating files:  82% (143/174)
# Updating files:  83% (145/174)
# Updating files:  84% (147/174)
# Updating files:  85% (148/174)
# Updating files:  86% (150/174)
# Updating files:  87% (152/174)
# Updating files:  88% (154/174)
# Updating files:  89% (155/174)
# Updating files:  90% (157/174)
# Updating files:  91% (159/174)
# Updating files:  92% (161/174)
# Updating files:  93% (162/174)
# Updating files:  94% (164/174)
# Updating files:  95% (166/174)
# Updating files:  96% (168/174)
# Updating files:  97% (169/174)
# Updating files:  98% (171/174)
# Updating files:  99% (173/174)
# ...

# %%
glob.glob('tennis_atp/atp_matches_[12][019][01298]*')
# Out:
# ['tennis_atp\\atp_matches_1980.csv',
#  'tennis_atp\\atp_matches_1981.csv',
#  'tennis_atp\\atp_matches_1982.csv',
#  'tennis_atp\\atp_matches_1983.csv',
#  'tennis_atp\\atp_matches_1984.csv',
#  'tennis_atp\\atp_matches_1985.csv',
#  'tennis_atp\\atp_matches_1986.csv',
#  'tennis_atp\\atp_matches_1987.csv',
#  'tennis_atp\\atp_matches_1988.csv',
#  'tennis_atp\\atp_matches_1989.csv',
#  'tennis_atp\\atp_matches_1990.csv',
#  'tennis_atp\\atp_matches_1991.csv',
#  'tennis_atp\\atp_matches_1992.csv',
#  'tennis_atp\\atp_matches_1993.csv',
#  'tennis_atp\\atp_matches_1994.csv',
#  'tennis_atp\\atp_matches_1995.csv',
#  'tennis_atp\\atp_matches_1996.csv',
#  'tennis_atp\\atp_matches_1997.csv',
#  'tennis_atp\\atp_matches_1998.csv',
#  'tennis_atp\\atp_matches_1999.csv',
#  'tennis_atp\\atp_matches_2000.csv',
#  'tennis_atp\\atp_matches_2001.csv',
#  'tennis_atp\\atp_matches_2002.csv',
#  'tennis_atp\\atp_matches_2003.csv',
#  'tennis_atp\\atp_matches_2004.csv',
# ...

# %%
df = pd.concat([pd.read_csv(i) for i in glob.glob('tennis_atp/atp_matches_[12][019][01298]*')], axis=0)

# %%
df
# Out:
#                             tourney_id                  tourney_name surface  \
# 0                            1980-1725              Pepsi Grand Slam    Clay
# 1                            1980-1725              Pepsi Grand Slam    Clay
# 2                            1980-1725              Pepsi Grand Slam    Clay
# 3                             1980-205                         Lagos    Clay
# 4                             1980-205                         Lagos    Clay
# ...                                ...                           ...     ...
# 2911  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 2912  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 2913  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
# 2914  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
# 2915  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
#
# ...

# %%
df.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points'],
#       dtype='object')

# %%
A=df[df['winner_rank'] > 36]
A
# Out:
#                             tourney_id                  tourney_name surface  \
# 3                             1980-205                         Lagos    Clay
# 19                            1980-205                         Lagos    Clay
# 27                            1980-205                         Lagos    Clay
# 31                            1980-205                         Lagos    Clay
# 33                            1980-205                         Lagos    Clay
# ...                                ...                           ...     ...
# 2909  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 2910  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 2911  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 2912  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 2913  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
#
# ...

# %%
B=df[df['winner_rank'] < 36]
B
# Out:
#                            tourney_id                  tourney_name surface  \
# 0                           1980-1725              Pepsi Grand Slam    Clay
# 1                           1980-1725              Pepsi Grand Slam    Clay
# 2                           1980-1725              Pepsi Grand Slam    Clay
# 34                           1980-206                         Cairo    Clay
# 50                           1980-206                         Cairo    Clay
# ...                               ...                           ...     ...
# 2802  2022-M-DC-2022-QLS-M-KAZ-NOR-01  Davis Cup QLS R1: KAZ vs NOR    Hard
# 2808  2022-M-DC-2022-QLS-M-USA-COL-01  Davis Cup QLS R1: USA vs COL    Hard
# 2840  2022-M-DC-2022-WG1-M-IND-NOR-01  Davis Cup WG1 R1: IND vs NOR    Hard
# 2898  2022-M-DC-2022-WG2-M-TUN-GRE-01  Davis Cup WG2 R1: TUN vs GRE    Hard
# 2900  2022-M-DC-2022-WG2-M-TUN-GRE-01  Davis Cup WG2 R1: TUN vs GRE    Hard
#
# ...

# %%
A['sets'] = A['score'].map(lambda x: len(x.split()))

# %%
A
# Out:
#                             tourney_id                  tourney_name surface  \
# 3                             1980-205                         Lagos    Clay
# 19                            1980-205                         Lagos    Clay
# 27                            1980-205                         Lagos    Clay
# 31                            1980-205                         Lagos    Clay
# 33                            1980-205                         Lagos    Clay
# ...                                ...                           ...     ...
# 2909  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 2910  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 2911  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 2912  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 2913  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
#
# ...

# %% [markdown]
# Невозможно выполнить то, что нам не объяснили. Раньше хотя бы на платформе прорешивалось задание подобное домашнему. Здесь - ничего подобного. Считаю пустой трату времени на выполнение того, чего не знаешь и не понимаешь. На платформе объяснено про автоматический анализ данных, здесь непонятно что, таблица не одна а много, она заархивирована, как открывать архивы никто не объяснил. Мы элементарно файл открывать не умеем, о каком анализе может идти речь. Почему SWEETVIZ не может открыть?

# %%
import pandas as pd
import sweetviz as sv


report = sv.analyze(df)
report.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 5>()
#       1 import pandas as pd
#       2 import sweetviz as sv
# ----> 5 report = sv.analyze(df)
#       6 report.show_html()
#
# File ~\anaconda3\lib\site-packages\sweetviz\sv_public.py:12, in analyze(source, target_feat, feat_cfg, pairwise_analysis)
#       8 def analyze(source: Union[pd.DataFrame, Tuple[pd.DataFrame, str]],
#       9             target_feat: str = None,
#      10             feat_cfg: FeatureConfig = None,
#      11             pairwise_analysis: str = 'auto'):
# ---> 12     report = sweetviz.DataframeReport(source, target_feat, None,
#      13                                       pairwise_analysis, feat_cfg)
#      14     return report
#
# ...
